# %%
import stable_retro as retro
env = retro.make(game='StreetFighter3rdStrike-Dreamcast-v0')
print("buttons:", env.buttons)
print("num_buttons:", env.num_buttons)
print("action_space:", env.action_space)
env.close()
# Out:
# buttons: ['A', 'B', 'X', 'Y', 'START', 'DPAD_UP', 'DPAD_DOWN', 'DPAD_LEFT', 'DPAD_RIGHT', 'L', 'R', None, None, None]
# num_buttons: 14
# action_space: MultiBinary(14)
# HWRender: init() called, context_type=6
# HWRender: Unsupported context type 6
# HWRender: init() called, context_type=3
# HWRender: calling initEGL()...
# libEGL warning: DRI3 error: Could not get DRI3 device
# libEGL warning: Ensure your X server supports DRI3 to get accelerated rendering
# HWRender: Using native X11 display
# HWRender: EGL 1.5 initialized, useSurfaceless=0
# HWRender: EGL Vendor: Mesa Project
# HWRender: EGL Version: 1.5
# HWRender: EGL_KHR_surfaceless_context supported: yes
# HWRender: Using OpenGL ES API (better virgl compatibility)
# HWRender: Bound OpenGL ES API
# HWRender: Using pbuffer mode
# HWRender: Got 1 config(s)
# HWRender: Config RENDERABLE_TYPE=0x4d (OpenGL=yes, ES3=yes), SURFACE_TYPE=0x407
# HWRender: Created pbuffer surface
# HWRender: Creating context (OpenGL ES 3)
# ...
